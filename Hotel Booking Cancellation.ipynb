# %% [markdown]
# # Problem Statement
#
# ## Given a hotel dataset, predict whether the customer will cancel the booking or not

# %% [markdown]
# ### Import necessary packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Loading Dataset

# %%
df =pd.read_csv('hotel_bookings.csv')

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.sample()
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 19814  Resort Hotel            0          1               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 19814            January                         2                          3
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 19814                        1                     0       2  ...
#
#        deposit_type  agent company days_in_waiting_list customer_type   adr  \
# 19814    No Deposit  240.0     NaN                    0     Transient  48.0
#
#        required_car_parking_spaces  total_of_special_requests  \
# 19814                            0                          1
#
#        reservation_status reservation_status_date
# 19814           Check-Out              2016-01-04
#
# [1 rows x 32 columns]

# %% [markdown]
# ## Checking the attribute's data types and presence of null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.describe().transpose()
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %%
df.describe(include = 'object').T
# Out:
#                           count unique         top    freq
# hotel                    119390      2  City Hotel   79330
# arrival_date_month       119390     12      August   13877
# meal                     119390      5          BB   92310
# country                  118902    177         PRT   48590
# market_segment           119390      8   Online TA   56477
# distribution_channel     119390      5       TA/TO   97870
# reserved_room_type       119390     10           A   85994
# assigned_room_type       119390     12           A   74053
# deposit_type             119390      3  No Deposit  104641
# customer_type            119390      4   Transient   89613
# reservation_status       119390      3   Check-Out   75166
# reservation_status_date  119390    926  2015-10-21    1461

# %% [markdown]
# ## Visualising null values

# %%
plt.figure(figsize= (10,10))
sns.heatmap(data = df.isna(), yticklabels=False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Treating Missing values

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [raw]
# company as got 112593 missing values
# total records is 119390.
#
# So, we can drop company column

# %%
df.drop('company', axis = 1, inplace = True)

# %% [raw]
# Country has got 488 missing values. Droping country is not considered a good idea.
# So, we will rename the missing values as 'other country'

# %%
df.country.fillna('Other Country', inplace = True)

# %%
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                               0
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %% [raw]
# Children column has got 4 missing values
# Agent column has got 16340 missing values
#
# so, we will drop the null values in this column

# %%
df.dropna(subset = ['agent', 'children'], inplace = True)

# %% [markdown]
# ## Heat map - showing correlation

# %%
plt.figure(figsize= (15, 15))
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Dependent variable - count plot

# %%
sns.countplot(x = df.is_canceled)
# Out:
# <AxesSubplot:xlabel='is_canceled', ylabel='count'>

# %%
# The feature is_canceled is slightly imbalanced

# %%
for i in df.select_dtypes('object'):
    sns.countplot(x = df[i])
    plt.figure()

# %% [markdown]
# ## Encoding categorical variables

# %%
# split the data into numeric and categorical

# %%
numeric = list(df.select_dtypes(exclude='O'))

# %%
categoric = list(df.select_dtypes(include='O'))

# %%
df = pd.get_dummies(columns=categoric, data = df, drop_first=True)
df.head()
# Out:
#    is_canceled  lead_time  arrival_date_year  arrival_date_week_number  \
# 3            0         13               2015                        27
# 4            0         14               2015                        27
# 5            0         14               2015                        27
# 7            0          9               2015                        27
# 8            1         85               2015                        27
#
#    arrival_date_day_of_month  stays_in_weekend_nights  stays_in_week_nights  \
# 3                          1                        0                     1
# 4                          1                        0                     2
# 5                          1                        0                     2
# 7                          1                        0                     2
# 8                          1                        0                     3
#
#    adults  children  babies  ...  reservation_status_date_2017-09-03  \
# ...

# %% [markdown]
# ## Splitting the data

# %%
x = df.drop('is_canceled', axis = 1)
y = df.is_canceled

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state= 0, test_size= 0.3)

# %% [markdown]
# ## Building the model

# %% [markdown]
# ## 1. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\91988\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x_train, y_train)*100
# Out:
# 97.3867716579097

# %%
model.score(x_test, y_test)*100
# Out:
# 97.38961669092674

# %% [raw]
# Logistic Regression
#
# Train Score 0.9738
# Test  Score 0.9738

# %% [markdown]
# ## 2. Random Forest Algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators =400 , 
                               random_state = 0)
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=400, random_state=0)

# %%
rf.score(x_train, y_train)*100
# Out:
# 100.0

# %%
rf.score(x_test, y_test)*100
# Out:
# 100.0

# %% [raw]
# RF
# Train Score: 100 percent
# Test Score : 100 percent

# %% [markdown]
# ## 3. Support Vector Machine

# %%
from sklearn import svm

# %%
support = svm.SVC(kernel = 'linear')

# %%
support.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
print(support.score(x_train, y_train))
print(support.score(x_test, y_test))
# Out:
# 1.0
# 1.0

# %% [raw]
# SVM
# Train Score:100 percent Accuracy
# Test  Score:100 percent Accuracy

# %% [markdown]
# # Conclusion:

# %% [raw]
# Random Forest Model and SVM model are giving hundred percent accuracy.
# But considering the time taken to tune your parameteres, I would go with Random forest model over SVM.
